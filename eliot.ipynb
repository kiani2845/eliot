# %%
from __future__ import annotations
from models.WavePattern import WavePattern
from models.WaveRules import Impulse, LeadingDiagonal
from models.WaveAnalyzer import WaveAnalyzer
from models.WaveOptions import WaveOptionsGenerator5
from models.helpers import plot_pattern, convert_yf_data
import pandas as pd
import numpy as np
import yfinance as yf
import tkinter as tk
from tkinter import messagebox, scrolledtext
import binance
#from binance.client import Client
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler

# تنظیمات API بایننس (وارد کنید)
API_KEY = 'your_api_key'
API_SECRET = 'your_api_secret'
#client = Client(API_KEY, API_SECRET)

def analyze_wave(stock_name, analysis_type):
    f = open(f"data/{stock_name.lower()}_1d.csv", "w")
  
    #try:
    df = yf.download(tickers=stock_name, interval="1d", start=input("please enter the start date(y-m-d)"))
    # اضافه کردن ستون date
    df['date'] = df.index
    df.reset_index(drop=True, inplace=True)
    if 'date' in df.columns:
        df['Date'] = df.index
        df.reset_index(drop=True, inplace=True)
         #df.rename(columns={'Date': 'date'}, inplace=True)  # تغییر نام ستون
    
    else:
        raise ValueError("The 'date' column does not exist in the DataFrame.")
        #convert_yf_data(df).to_csv(f'data/{stock_name.lower()}_1d.csv', sep=",", index=True)
       
    idx_start = np.argmin(np.array(list(df['Low'])))
    wa = WaveAnalyzer(df=df, verbose=False)
    wave_options_impulse = WaveOptionsGenerator5(up_to=15)
        
    impulse = Impulse('impulse')
    leading_diagonal = LeadingDiagonal('leading diagonal')
    rules_to_check = [impulse, leading_diagonal]

    wavepatterns_up = set()
    results = []

    for new_option_impulse in wave_options_impulse.options_sorted:
        waves_up = wa.find_impulsive_wave(idx_start=idx_start, wave_config=new_option_impulse.values)
        if waves_up:
            wavepattern_up = WavePattern(waves_up, verbose=True)
            for rule in rules_to_check:
                if wavepattern_up.check_rule(rule):
                    if wavepattern_up in wavepatterns_up:
                        continue
                    else:
                        wavepatterns_up.add(wavepattern_up)
                        result = f'{rule.name} found: {new_option_impulse.values}'
                        results.append(result)
                        print(result)
                        plot_pattern(df=df, wave_pattern=wavepattern_up, title=str(new_option_impulse))

    result_display = "\n".join(results) if results else "هیچ الگوی معتبری پیدا نشد."
    result_text.config(state=tk.NORMAL)
    result_text.delete(1.0, tk.END)
    result_text.insert(tk.END, result_display)
    result_text.config(state=tk.DISABLED)

        # تحلیل قیمت با استفاده از شبکه‌های عصبی
    neural_network_results = neural_network_analysis(df)

        # ذخیره تحلیل‌ها در HTML
    save_analysis_to_html(stock_name, results, neural_network_results)

        # نمایش گرافیکی تحلیل‌ها
    plot_analysis(df)
    print(plot_analysis(df))
    

        # معامله خودکار (ایجاد یک مثال ساده)
    if analysis_type == 'خرید':
        order = client.order_market_buy(
            symbol=stock_name,  # جایگزین با نام سهم مورد نظر
            quantity=input('your quantity')  # مقدار مورد نظر
        )
        print("معامله انجام شد:", order)

    #except Exception as e:
        #messagebox.showerror("خطا", str(e))

def neural_network_analysis(df):
    # پیش‌پردازش داده‌ها
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(df['Close'].values.reshape(-1, 1))
    
    if len(scaled_data) <= 60:
        raise ValueError("Not enough data points to create train_data. Need at least 60.")

    train_data = []
    for i in range(60, len(scaled_data)):
        train_data.append(scaled_data[i-60:i, 0])

    train_data = np.array(train_data)
    
    if len(train_data) == 0:
        raise ValueError("Not enough data to create train_data.")

    # شکل‌دهی داده‌ها به فرمت ورودی شبکه
    X_train = np.reshape(train_data, (train_data.shape[0], train_data.shape[1]))  # دو بعدی

    # ساخت مدل شبکه عصبی
    model = Sequential()
    model.add(Dense(units=50, activation='relu', input_shape=(X_train.shape[1], 1)))
    model.add(Dense(units=25))
    model.add(Dense(units=1))

    model.compile(optimizer='adam', loss='mean_squared_error')
    
    # آموزش مدل
    model.fit(X_train, scaled_data[60:], epochs=100, batch_size=32)

    # پیش‌بینی قیمت
    predicted_price = model.predict(X_train)

# تغییر ابعاد predicted_price
    predicted_price = predicted_price.reshape(-1, 1)

# حالا می‌توانید inverse_transform را اجرا کنید
    predicted_price = scaler.inverse_transform(predicted_price)

    return predicted_price.flatten()  # بازگشت قیمت پیش‌بینی شده

def save_analysis_to_html(stock_name, wave_results, neural_network_results):
    with open('index.html', 'w', encoding='utf-8') as f:
        f.write('<html><head><title>تحلیل قیمت</title></head><body>')
        f.write(f'<h1>تحلیل قیمت سهام: {stock_name}</h1>')
        
        f.write('<h2>نتایج تحلیل امواج الیوت</h2>')
        f.write('<ul>')
        for result in wave_results:
            f.write(f'<li>{result}</li>')
        f.write('</ul>')

        f.write('<h2>نتایج پیش‌بینی با شبکه‌های عصبی</h2>')
        f.write('<ul>')
        for price in neural_network_results:
            f.write(f'<li>{price:.2f}</li>')
        f.write('</ul>')

        f.write('</body></html>')
    messagebox.showinfo("ذخیره‌سازی", "تحلیل‌ها با موفقیت در فایل index.html ذخیره شد.")

def plot_analysis(df):
    plt.figure(figsize=(12, 6))

    # نمودار قیمت
    plt.subplot(2, 1, 1)
    plt.plot(df['Close'], label='Closing price', color='blue')
    plt.title('Stock price chart')
    plt.xlabel('date')
    plt.ylabel('price')
    plt.legend()

    # میانگین متحرک
    df['SMA20'] = df['Close'].rolling(window=20).mean()
    df['SMA50'] = df['Close'].rolling(window=50).mean()
    plt.plot(df['SMA20'], label='20 day moving average', color='orange')
    plt.plot(df['SMA50'], label='50 day moving average', color='red')
    plt.legend()

    plt.subplot(2, 1, 2)
    plt.title('Chart of price changes')
    plt.plot(df['Close'].pct_change(), label='Price changes', color='green')
    plt.xlabel('date')
    plt.ylabel('Percentage changes')
    plt.legend()

    plt.tight_layout()
    plt.show()

def on_button_click():
    stock_name = entry.get()
    analysis_type = analysis_var.get()
    if stock_name:
        analyze_wave(stock_name, analysis_type)
    else:
        messagebox.showwarning("ورودی نامعتبر", "لطفاً نام سهم را وارد کنید.")

# ایجاد رابط کاربری با tkinter
root = tk.Tk()
root.title("تحلیل امواج الیوت")

label = tk.Label(root, text="نام سهم را وارد کنید:")
label.pack()

entry = tk.Entry(root)
entry.pack()

analysis_var = tk.StringVar(value='خرید')
analysis_type_frame = tk.Frame(root)
tk.Radiobutton(analysis_type_frame, text='خرید', variable=analysis_var, value='خرید').pack(side=tk.LEFT)
tk.Radiobutton(analysis_type_frame, text='فروش', variable=analysis_var, value='فروش').pack(side=tk.LEFT)
analysis_type_frame.pack()

button = tk.Button(root, text="تحلیل", command=on_button_click)
button.pack()

result_text = scrolledtext.ScrolledText(root, wrap=tk.WORD, width=50, height=10)
result_text.pack()
result_text.config(state=tk.DISABLED)

root.mainloop()
# Out:
# please enter the start date(y-m-d) 2024-07-02
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w4_1: End of Wave4 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w5_1: End of Wave5 is lower than End of Wave3
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 74, in analyze_wave
#     neural_network_results = neural_network_analysis(df)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 101, in neural_network_analysis
#     raise ValueError("Not enough data points to create train_data. Need at least 60.")
# ValueError: Not enough data points to create train_data. Need at least 60.
# please enter the start date(y-m-d) 2024-06-02
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w4_1: End of Wave4 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w5_1: End of Wave5 is lower than End of Wave3
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 74, in analyze_wave
#     neural_network_results = neural_network_analysis(df)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 101, in neural_network_analysis
#     raise ValueError("Not enough data points to create train_data. Need at least 60.")
# ValueError: Not enough data points to create train_data. Need at least 60.
# please enter the start date(y-m-d) 2024-05-01
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w4_1: End of Wave4 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w5_1: End of Wave5 is lower than End of Wave3
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 74, in analyze_wave
#     neural_network_results = neural_network_analysis(df)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 101, in neural_network_analysis
#     raise ValueError("Not enough data points to create train_data. Need at least 60.")
# ValueError: Not enough data points to create train_data. Need at least 60.
# please enter the start date(y-m-d) 2024-04-30
# [*********************100%***********************]  1 of 1 completed
# impulse found: [0, 0, 0, 0, 0]
# Rule Violation of leading diagonal for condition w4_1: End of Wave4 is not lower than End of Wave1
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w4_2: Length of Wave4 is shorter than 1/3 of End of Wave1
# Rule Violation of leading diagonal for condition w4_1: End of Wave4 is not lower than End of Wave1
# Rule Violation of impulse for condition w4_1: End of Wave4 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w5_1: End of Wave5 is lower than End of Wave3
# Rule Violation of impulse for condition w4_1: End of Wave4 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w5_1: End of Wave5 is lower than End of Wave3
# Rule Violation of impulse for condition w4_1: End of Wave4 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w5_1: End of Wave5 is lower than End of Wave3
# Rule Violation of impulse for condition w4_1: End of Wave4 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w5_1: End of Wave5 is lower than End of Wave3
# Rule Violation of impulse for condition w4_1: End of Wave4 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w5_1: End of Wave5 is lower than End of Wave3
# Rule Violation of impulse for condition w4_1: End of Wave4 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w5_1: End of Wave5 is lower than End of Wave3
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Epoch 1/100
# C:\Users\User\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.4754
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4199
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3697
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3220
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2783
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2463
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1988
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1707
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1426
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1183
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1003
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0803
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0613
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0533
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0495
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0443
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0407
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0374
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0374
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0406
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0408
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0410
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0402
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0407
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0402
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0375
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0346
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0373
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0347
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0350
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0326
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0317
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0336
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0306
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0328
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0294
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0315
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0308
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0312
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0292
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0287
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0305
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0296
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0291
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0273
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0288
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0281
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.0275
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0267
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.0261
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0270
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0253
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.0252
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0255
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0255
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0261
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.0236
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0239
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0243
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0248
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0237
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0225
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0244
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0235
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0218
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 0.0242
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0237
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0234
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0229
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0230
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0231
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0234
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0214
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0206
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0209
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0220
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0214
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0210
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0208
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0214
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0212
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0199
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0212
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0208
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0216
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0206
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0209
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0189
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0190
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0187
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0203
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0196
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0198
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0185
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0179
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0195
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0187
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0198
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0182
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0187
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000239708D7D80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# None
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 86, in analyze_wave
#     order = client.order_market_buy(
#             ^^^^^^
# NameError: name 'client' is not defined
# please enter the start date(y-m-d) 2024-06-01
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# impulse found: [1, 0, 0, 0, 0]
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Epoch 1/100
# C:\Users\User\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.6375
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.5948
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.5538
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.5145
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.4768
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.4406
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.4061
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3731
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.3418
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.3121
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.2840
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.2575
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2327
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2095
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1880
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1681
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1498
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.1331
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1181
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1046
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0927
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0823
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0734
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0658
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0596
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0546
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0507
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0479
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0460
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0448
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0443
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0443
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0447
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0453
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0461
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0468
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0475
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0481
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0484
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0486
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0485
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0482
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0477
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0470
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0462
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0453
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0442
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0432
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0422
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0412
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0402
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0393
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0385
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0377
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0370
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0365
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0359
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0355
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0351
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0348
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0344
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0342
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0339
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0336
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0334
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0331
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0328
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0325
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0322
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0319
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0316
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0313
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0309
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0306
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0302
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0299
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0296
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0292
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0289
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0286
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0282
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0279
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0276
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0273
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0271
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0268
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0265
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0262
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0260
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0257
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0255
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0252
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0250
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0247
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0245
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0242
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0240
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0237
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0235
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0232
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# None
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 86, in analyze_wave
#     order = client.order_market_buy(
#             ^^^^^^
# NameError: name 'client' is not defined
# please enter the start date(y-m-d) 2024-09-01
# [*********************100%***********************]  1 of 1 completed
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 53, in analyze_wave
#     waves_up = wa.find_impulsive_wave(idx_start=idx_start, wave_config=new_option_impulse.values)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\models\WaveAnalyzer.py", line 98, in find_impulsive_wave
#     if wave2.low > np.min(self.lows[wave2.low_idx:wave4.low_idx]):
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 2953, in min
#     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 88, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: zero-size array to reduction operation minimum which has no identity
# please enter the start date(y-m-d) 2024-08-09
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 74, in analyze_wave
#     neural_network_results = neural_network_analysis(df)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 101, in neural_network_analysis
#     raise ValueError("Not enough data points to create train_data. Need at least 60.")
# ValueError: Not enough data points to create train_data. Need at least 60.
# please enter the start date(y-m-d) 2024-08-01
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_5: Wave3 more than 7 times longer than Wave1.
# Rule Violation of leading diagonal for condition w3_5: Wave3 more than 7 times longer than Wave1.
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of impulse for condition w4_1: End of Wave4 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 74, in analyze_wave
#     neural_network_results = neural_network_analysis(df)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 101, in neural_network_analysis
#     raise ValueError("Not enough data points to create train_data. Need at least 60.")
# ValueError: Not enough data points to create train_data. Need at least 60.
# please enter the start date(y-m-d) 2024-08-11
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 74, in analyze_wave
#     neural_network_results = neural_network_analysis(df)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 101, in neural_network_analysis
#     raise ValueError("Not enough data points to create train_data. Need at least 60.")
# ValueError: Not enough data points to create train_data. Need at least 60.
# please enter the start date(y-m-d) 2024-08-20
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 74, in analyze_wave
#     neural_network_results = neural_network_analysis(df)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 101, in neural_network_analysis
#     raise ValueError("Not enough data points to create train_data. Need at least 60.")
# ValueError: Not enough data points to create train_data. Need at least 60.
# please enter the start date(y-m-d) 2024-08-25
# [*********************100%***********************]  1 of 1 completed
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 53, in analyze_wave
#     waves_up = wa.find_impulsive_wave(idx_start=idx_start, wave_config=new_option_impulse.values)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\models\WaveAnalyzer.py", line 98, in find_impulsive_wave
#     if wave2.low > np.min(self.lows[wave2.low_idx:wave4.low_idx]):
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 2953, in min
#     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 88, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: zero-size array to reduction operation minimum which has no identity
# please enter the start date(y-m-d) 2024-08-23
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 74, in analyze_wave
#     neural_network_results = neural_network_analysis(df)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 101, in neural_network_analysis
#     raise ValueError("Not enough data points to create train_data. Need at least 60.")
# ValueError: Not enough data points to create train_data. Need at least 60.
# please enter the start date(y-m-d) 2024-08-24
# [*********************100%***********************]  1 of 1 completed
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 53, in analyze_wave
#     waves_up = wa.find_impulsive_wave(idx_start=idx_start, wave_config=new_option_impulse.values)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\models\WaveAnalyzer.py", line 98, in find_impulsive_wave
#     if wave2.low > np.min(self.lows[wave2.low_idx:wave4.low_idx]):
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 2953, in min
#     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 88, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: zero-size array to reduction operation minimum which has no identity
# please enter the start date(y-m-d) 2024-07-24
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_5: Wave3 more than 7 times longer than Wave1.
# Rule Violation of leading diagonal for condition w3_5: Wave3 more than 7 times longer than Wave1.
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of impulse for condition w4_1: End of Wave4 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 74, in analyze_wave
#     neural_network_results = neural_network_analysis(df)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 101, in neural_network_analysis
#     raise ValueError("Not enough data points to create train_data. Need at least 60.")
# ValueError: Not enough data points to create train_data. Need at least 60.
# please enter the start date(y-m-d) 2024-07-01
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 74, in analyze_wave
#     neural_network_results = neural_network_analysis(df)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 101, in neural_network_analysis
#     raise ValueError("Not enough data points to create train_data. Need at least 60.")
# ValueError: Not enough data points to create train_data. Need at least 60.
# please enter the start date(y-m-d) 2024-06-31
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['LTC']: ValueError('day is out of range for month')
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 41, in analyze_wave
#     idx_start = np.argmin(np.array(list(df['Low'])))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 1325, in argmin
#     return _wrapfunc(a, 'argmin', axis=axis, out=out, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 59, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: attempt to get argmin of an empty sequence
# please enter the start date(y-m-d) 2024-06-30
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# ...
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 41, in analyze_wave
#     idx_start = np.argmin(np.array(list(df['Low'])))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 1325, in argmin
#     return _wrapfunc(a, 'argmin', axis=axis, out=out, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 59, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: attempt to get argmin of an empty sequence
# please enter the start date(y-m-d) 01
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SQL']: ValueError("time data '01' does not match format '%Y-%m-%d'")
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 41, in analyze_wave
#     idx_start = np.argmin(np.array(list(df['Low'])))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 1325, in argmin
#     return _wrapfunc(a, 'argmin', axis=axis, out=out, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 59, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: attempt to get argmin of an empty sequence
# please enter the start date(y-m-d) 2024-09-01
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SHIB']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 41, in analyze_wave
#     idx_start = np.argmin(np.array(list(df['Low'])))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 1325, in argmin
#     return _wrapfunc(a, 'argmin', axis=axis, out=out, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 59, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: attempt to get argmin of an empty sequence
# please enter the start date(y-m-d) 2024-09-20
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SHIB']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 41, in analyze_wave
#     idx_start = np.argmin(np.array(list(df['Low'])))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 1325, in argmin
#     return _wrapfunc(a, 'argmin', axis=axis, out=out, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 59, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: attempt to get argmin of an empty sequence
# please enter the start date(y-m-d) 2024-09-01
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAB']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-09-01 -> 2024-09-23)')
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 41, in analyze_wave
#     idx_start = np.argmin(np.array(list(df['Low'])))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 1325, in argmin
#     return _wrapfunc(a, 'argmin', axis=axis, out=out, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 59, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: attempt to get argmin of an empty sequence
# please enter the start date(y-m-d) 2024-08-01
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAB']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2024-08-01 -> 2024-09-23)')
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 41, in analyze_wave
#     idx_start = np.argmin(np.array(list(df['Low'])))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 1325, in argmin
#     return _wrapfunc(a, 'argmin', axis=axis, out=out, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py", line 59, in _wrapfunc
#     return bound(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^^
# ValueError: attempt to get argmin of an empty sequence
# please enter the start date(y-m-d) 2024-09-01
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w4_1: End of Wave4 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 74, in analyze_wave
#     neural_network_results = neural_network_analysis(df)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 101, in neural_network_analysis
#     raise ValueError("Not enough data points to create train_data. Need at least 60.")
# ValueError: Not enough data points to create train_data. Need at least 60.
# please enter the start date(y-m-d) 2024-08-24
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w4_1: End of Wave4 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 74, in analyze_wave
#     neural_network_results = neural_network_analysis(df)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 101, in neural_network_analysis
#     raise ValueError("Not enough data points to create train_data. Need at least 60.")
# ValueError: Not enough data points to create train_data. Need at least 60.
# please enter the start date(y-m-d) 2024-08-01
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_5: Wave3 more than 7 times longer than Wave1.
# Rule Violation of leading diagonal for condition w3_5: Wave3 more than 7 times longer than Wave1.
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 74, in analyze_wave
#     neural_network_results = neural_network_analysis(df)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 101, in neural_network_analysis
#     raise ValueError("Not enough data points to create train_data. Need at least 60.")
# ValueError: Not enough data points to create train_data. Need at least 60.
# please enter the start date(y-m-d) 2024-07-10
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 74, in analyze_wave
#     neural_network_results = neural_network_analysis(df)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 101, in neural_network_analysis
#     raise ValueError("Not enough data points to create train_data. Need at least 60.")
# ValueError: Not enough data points to create train_data. Need at least 60.
# please enter the start date(y-m-d) 2024-07-01
# [*********************100%***********************]  1 of 1 completed
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of impulse for condition w2_3: Wave2 is longer than 9x Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_1: Wave3 is the shortest Wave.
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Rule Violation of impulse for condition w3_2: End of Wave3 is lower than End of Wave1
# Rule Violation of leading diagonal for condition w2_0: Trend lines of Wave1-3 and Wave2-4 not forming Leading Diagonal.
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 189, in on_button_click
#     analyze_wave(stock_name, analysis_type)
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 74, in analyze_wave
#     neural_network_results = neural_network_analysis(df)
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\User\AppData\Local\Temp\ipykernel_16084\1012788012.py", line 101, in neural_network_analysis
#     raise ValueError("Not enough data points to create train_data. Need at least 60.")
# ValueError: Not enough data points to create train_data. Need at least 60.
